# %%
import pandas as pd
import numpy as np

df = pd.read_csv('auto-mpg.csv', header = None)

df.columns = ['mpg', 'cylinders','displacement','horsepower', 'weight',
              'acceleration', 'model year', 'origin', 'name']

df['horsepower'].replace('?', np.nan, inplace = True)
df.dropna(subset = ['horsepower'], axis = 0, inplace = True)
df['horsepower'] = df['horsepower'].astype('float')

df.horsepower.describe()
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %%
df.horsepower = df.horsepower/abs(df.horsepower.max())

# %%
df.horsepower.head()
# Out:
# 0    0.565217
# 1    0.717391
# 2    0.652174
# 3    0.652174
# 4    0.608696
# Name: horsepower, dtype: float64

# %%
df.horsepower.describe()
# Out:
# count    392.000000
# mean       0.454215
# std        0.167353
# min        0.200000
# 25%        0.326087
# 50%        0.406522
# 75%        0.547826
# max        1.000000
# Name: horsepower, dtype: float64

# %%
# horsepower 열의 통계 요약 정보로 최대값과 최소값 확인
# horsepower 열의 최대값과 절대값으로 모든 데이터를 나눠서 저장
# 최대값과 최소값의 차를 이용하여 데이터를 정규화 하면 0~!사이에 다 들어옴
min_x = df.horsepower - df.horsepower.min()
min_max = df.horsepower.max() - df.horsepower.min()
df.horsepower = min_x / min_max

print(df.horsepower.head())
df.horsepower.describe()
# Out:
# 0    0.456522
# 1    0.646739
# 2    0.565217
# 3    0.565217
# 4    0.510870
# Name: horsepower, dtype: float64
# count    392.000000
# mean       0.317768
# std        0.209191
# min        0.000000
# 25%        0.157609
# 50%        0.258152
# 75%        0.434783
# max        1.000000
# Name: horsepower, dtype: float64

# %%
import pandas as pd

df = pd.read_csv('stock-data.csv')

print(df.head())
df.info()
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
df['new_Date'] = pd.to_datetime(df['Date'])

print(df.head(), df.info(), df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20 non-null     object
#  1   Close     20 non-null     int64
#  2   Start     20 non-null     int64
#  3   High      20 non-null     int64
#  4   Low       20 non-null     int64
#  5   Volume    20 non-null     int64
#  6   new_Date  20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.2+ KB
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# ...

# %%
type(df['new_Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('new_Date', inplace = True)
df.drop('Date', axis = 1, inplace = True)

print(df.head(), df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2018-07-02 to 2018-06-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   20 non-null     int64
#  1   Start   20 non-null     int64
#  2   High    20 non-null     int64
#  3   Low     20 non-null     int64
#  4   Volume  20 non-null     int64
# dtypes: int64(5)
# memory usage: 960.0 bytes
#             Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  10800  10900  11000  10700   63039 None

# %%
import pandas as pd

dates = ['2019-01-01', '2020-03-01', '2021-06-01']

ts_dates = pd.to_datetime(dates)
print(ts_dates)

pr_day = ts_dates.to_period(freq ='D')
print(pr_day)

pr_month = ts_dates.to_period(freq = 'M')
print(pr_month)

pr_year = ts_dates.to_period(freq = 'A')
print(pr_year)
# Out:
# DatetimeIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='datetime64[ns]', freq=None)
# PeriodIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='period[D]', freq='D')
# PeriodIndex(['2019-01', '2020-03', '2021-06'], dtype='period[M]', freq='M')
# PeriodIndex(['2019', '2020', '2021'], dtype='period[A-DEC]', freq='A-DEC')

# %%
import pandas as pd
# periods = 6번 반복, freq = MS:월초!!
ts_ms = pd.date_range(start = '2019-01-01',
                      end = None,
                      periods = 6,
                      freq = 'MS',
                      tz = 'Asia/Seoul')
ts_ms
# Out:
# DatetimeIndex(['2019-01-01 00:00:00+09:00', '2019-02-01 00:00:00+09:00',
#                '2019-03-01 00:00:00+09:00', '2019-04-01 00:00:00+09:00',
#                '2019-05-01 00:00:00+09:00', '2019-06-01 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='MS')

# %%
ts_me = pd.date_range('2019-01-01', periods = 6, freq = 'M',
                      tz = 'Asia/Seoul')
print(ts_me)
# Out:
# DatetimeIndex(['2019-01-31 00:00:00+09:00', '2019-02-28 00:00:00+09:00',
#                '2019-03-31 00:00:00+09:00', '2019-04-30 00:00:00+09:00',
#                '2019-05-31 00:00:00+09:00', '2019-06-30 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='M')

# %%
ts_3m  = pd.date_range('2019-01-01', periods = 6,
                       freq = '3M',
                       tz = 'Asia/Seoul')

# %%
ts_3m
# Out:
# DatetimeIndex(['2019-01-31 00:00:00+09:00', '2019-04-30 00:00:00+09:00',
#                '2019-07-31 00:00:00+09:00', '2019-10-31 00:00:00+09:00',
#                '2020-01-31 00:00:00+09:00', '2020-04-30 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='3M')

# %%
import pandas as pd

pr_m = pd.period_range(start = '2019-01-01',
                       end = None,
                       periods = 3,
                       freq = 'M')
print(pr_m)
# Out:
# PeriodIndex(['2019-01', '2019-02', '2019-03'], dtype='period[M]', freq='M')

# %%
pr_h = pd.period_range(start = '2019-01-01',
                       end = None,
                       periods = 3,
                       freq = 'H')
print(pr_h)

pr_2h = pd.period_range(start = '2019-01-01',
                       end = None,
                       periods = 3,
                       freq = '2H')
print(pr_2h)
# Out:
# PeriodIndex(['2019-01-01 00:00', '2019-01-01 01:00', '2019-01-01 02:00'], dtype='period[H]', freq='H')
# PeriodIndex(['2019-01-01 00:00', '2019-01-01 02:00', '2019-01-01 04:00'], dtype='period[2H]', freq='2H')

# %%
import pandas as pd

df = pd.read_csv('stock-data.csv')

#to_datetime으로 전달하면 Timestamp로 변환 -> df.day, dt.month, dt.year로 날짜 추출 가능
df['new_Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26

# %%
df['Year'] = df['new_Date'].dt.year
df['Month'] = df['new_Date'].dt.month
df['Day'] = df['new_Date'].dt.day
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  Day
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02  2018      7    2
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6   29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6   28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6   27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6   26

# %%
df['Date_yr'] = df['new_Date'].dt.to_period(freq = 'A')
df['Date_m'] = df['new_Date'].dt.to_period(freq = 'M')
df.head()
# Out:
#          Date  Close  Start   High    Low  ...  Month Day  Date_yr   Date_d   Date_m
# 0  2018-07-02  10100  10850  10900  10000  ...      7   2     2018  2018-07  2018-07
# 1  2018-06-29  10700  10550  10900   9990  ...      6  29     2018  2018-06  2018-06
# 2  2018-06-28  10400  10900  10950  10150  ...      6  28     2018  2018-06  2018-06
# 3  2018-06-27  10900  10800  11050  10500  ...      6  27     2018  2018-06  2018-06
# 4  2018-06-26  10800  10900  11000  10700  ...      6  26     2018  2018-06  2018-06
#
# [5 rows x 13 columns]

# %%
df.set_index('Date_m', inplace = True)
print(df.head())
# Out:
#                Date  Close  Start   High  ...  Month  Day Date_yr   Date_d
# Date_m                                    ...
# 2018-07  2018-07-02  10100  10850  10900  ...      7    2    2018  2018-07
# 2018-06  2018-06-29  10700  10550  10900  ...      6   29    2018  2018-06
# 2018-06  2018-06-28  10400  10900  10950  ...      6   28    2018  2018-06
# 2018-06  2018-06-27  10900  10800  11050  ...      6   27    2018  2018-06
# 2018-06  2018-06-26  10800  10900  11000  ...      6   26    2018  2018-06
#
# [5 rows x 12 columns]

# %%
import pandas as pd

df = pd.read_csv('stock-data.csv')

#to_datetime으로 전달하면 Timestamp로 변환 -> df.day, dt.month, dt.year로 날짜 추출 가능
df['new_Date'] = pd.to_datetime(df['Date'])
df.set_index('new_Date', inplace = True)

print(df.head())
df.index
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039
# DatetimeIndex(['2018-07-02', '2018-06-29', '2018-06-28', '2018-06-27',
#                '2018-06-26', '2018-06-25', '2018-06-22', '2018-06-21',
#                '2018-06-20', '2018-06-19', '2018-06-18', '2018-06-15',
#                '2018-06-14', '2018-06-12', '2018-06-11', '2018-06-08',
#                '2018-06-07', '2018-06-05', '2018-06-04', '2018-06-01'],
#               dtype='datetime64[ns]', name='new_Date', freq=None)

# %%
df_y = df['2018']
print(df_y.head())
print('\n')

df_ym = df.loc['2018-07']
print(df_ym)
print('\n')

df_ym_cols = df.loc['2018-07', 'Start' : 'High']
print(df_ym_cols)
print('\n')

df_ymd = df['2018-07-02']
print(df_ymd)
print('\n')

df_ymd_range = df['2018-06-25':'2018-06-20']
print(df_ymd_range)
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039
#
#
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
#
#
#             Start   High
# new_Date
# 2018-07-02  10850  10900
#
#
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
#
#
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-25  2018-06-25  11150  11400  11450  11000   55519
# 2018-06-22  2018-06-22  11300  11250  11450  10750  134805
# 2018-06-21  2018-06-21  11200  11350  11750  11200  133002
# ...

# %%
today = pd.to_datetime('2018-12-25')
df['time_delta'] = today - df.index
df.set_index('time_delta', inplace = True)
df_180 = df['180 days' :'189 days']
print(df_180)
# Out:
#                   Date  Close  Start   High    Low  Volume
# time_delta
# 180 days    2018-06-28  10400  10900  10950  10150  155769
# 181 days    2018-06-27  10900  10800  11050  10500  133548
# 182 days    2018-06-26  10800  10900  11000  10700   63039
# 183 days    2018-06-25  11150  11400  11450  11000   55519
# 186 days    2018-06-22  11300  11250  11450  10750  134805
# 187 days    2018-06-21  11200  11350  11750  11200  133002
# 188 days    2018-06-20  11550  11200  11600  10900  308596
# 189 days    2018-06-19  11300  11850  11950  11300  180656
